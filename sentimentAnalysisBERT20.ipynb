# %% [markdown]
# <a href="https://colab.research.google.com/github/krenarep/sentimentAnalysis_1/blob/master/sentimentAnalysisBERT20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis with Deep Learning using BERT

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# ### Prerequisites

# %% [markdown]
# - Intermediate-level knowledge of Python 3 (NumPy and Pandas preferably, but not required)
# - Exposure to PyTorch usage
# - Basic understanding of Deep Learning and Language Models (BERT specifically)

# %% [markdown]
# ### Project Outline

# %% [markdown]
# **Task 1**: Introduction (this section)
#
# **Task 2**: Exploratory Data Analysis and Preprocessing
#
# **Task 3**: Training/Validation Split
#
# **Task 4**: Loading Tokenizer and Encoding our Data
#
# **Task 5**: Setting up BERT Pretrained Model
#
# **Task 6**: Creating Data Loaders
#
# **Task 7**: Setting Up Optimizer and Scheduler
#
# **Task 8**: Defining our Performance Metrics
#
# **Task 9**: Creating our Training Loop
#
# **Task 10**: Loading and Evaluating our Model

# %% [markdown]
# ## Task 1: Introduction

# %% [markdown]
# ### What is BERT
#
# BERT is a large-scale transformer-based Language Model that can be finetuned for a variety of tasks.
#
# For more information, the original paper can be found [here](https://arxiv.org/abs/1810.04805).
#
# [HuggingFace documentation](https://huggingface.co/transformers/model_doc/bert.html)
#
# [Bert documentation](https://characters.fandom.com/wiki/Bert_(Sesame_Street) ;)

# %% [markdown]
# <img src="Images/BERT_diagrams.pdf" width="1000">

# %% [markdown]
# ## Task 2: Exploratory Data Analysis and Preprocessing

# %% [markdown]
# We will use the SMILE Twitter dataset.
#
# _Wang, Bo; Tsakalidis, Adam; Liakata, Maria; Zubiaga, Arkaitz; Procter, Rob; Jensen, Eric (2016): SMILE Twitter Emotion dataset. figshare. Dataset. https://doi.org/10.6084/m9.figshare.3187909.v2_

# %%
import torch
import pandas as pd
from tqdm.notebook import tqdm

# %%
df = pd.read_csv(
    '/content/training.csv',
    names = ['id','text', 'category', 'aspects']             
    )
df.set_index('id', inplace=True)

# %%
df.head()
# Out:
#                                                  text  category  aspects
# id
# id                                               text  category  aspects
# 1   Due to the situation created as a result of th...  Negative        I
# 2   During the lectures there were also various pr...  Positive        X
# 3   In general I can say that during this difficul...  Positive        M
# 4   This situation has continued even during the e...  Negative        G

# %%
df.text.iloc[1]
# Out:
# 'Due to the situation created as a result of the pandemic, we, like most institutions in Kosovo, have been forced to attend online lectures'

# %%
df.category.value_counts()
# Out:
# Positive    354
# Negative     79
# Neutral      66
# category      1
# Name: category, dtype: int64

# %%
df = df[~df.category.str.contains('\|')]

# %%
df = df[df.category != 'category']

# %%
df.category.value_counts()
# Out:
# Positive    354
# Negative     79
# Neutral      66
# Name: category, dtype: int64

# %%
possible_labels = df.category.unique ()

# %%
label_dict = {}
for index, possible_labels in enumerate(possible_labels):
  label_dict[possible_labels] = index

# %%
label_dict
# Out:
# {'Negative': 0, 'Positive': 1, 'Neutral': 2}

# %%
df['label'] = df.category.replace(label_dict)
df.head()
# Out:
#                                                  text  category aspects  label
# id
# 1   Due to the situation created as a result of th...  Negative       I      0
# 2   During the lectures there were also various pr...  Positive       X      1
# 3   In general I can say that during this difficul...  Positive       M      1
# 4   This situation has continued even during the e...  Negative       G      0
# 5   The same process was followed in the Human-Com...   Neutral       L      2

# %% [markdown]
# ## Task 3: Training/Validation Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_val, y_train, y_val = train_test_split(
    df.index.values,
    df.label.values,
    test_size=0.15,
    random_state=17,
    stratify=df.label.values
    )

# %%
df['data_type'] = ['not_set']* df.shape[0]

# %%
df.head()
# Out:
#                                                  text  category aspects  \
# id
# 1   Due to the situation created as a result of th...  Negative       I
# 2   During the lectures there were also various pr...  Positive       X
# 3   In general I can say that during this difficul...  Positive       M
# 4   This situation has continued even during the e...  Negative       G
# 5   The same process was followed in the Human-Com...   Neutral       L
#
#     label data_type
# id
# 1       0   not_set
# 2       1   not_set
# 3       1   not_set
# 4       0   not_set
# 5       2   not_set

# %%
df.loc[X_train, 'data_type'] = 'train'
df.loc[X_val, 'data_type'] = 'val'

# %%
df.groupby(['category','label','data_type']).count()
# Out:
#                           text  aspects
# category label data_type
# Negative 0     train        67       67
#                val          12       12
# Neutral  2     train        56       56
#                val          10       10
# Positive 1     train       301      301
#                val          53       53

# %% [markdown]
# ## Task 4: Loading Tokenizer and Encoding our Data

# %%
pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.23.1-py3-none-any.whl (5.3 MB)
#      |████████████████████████████████| 5.3 MB 30.5 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.13.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.1-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      |████████████████████████████████| 7.6 MB 43.9 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting huggingface-hub<1.0,>=0.10.0
#   Downloading huggingface_hub-0.10.1-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 74.1 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.9.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Installing collected packages: tokenizers, huggingface-hub, transformers
# Successfully installed huggingface-hub-0.10.1 tokenizers-0.13.1 transformers-4.23.1

# %%
from transformers import BertTokenizer
from torch.utils.data import TensorDataset

# %%
tokenizer = BertTokenizer.from_pretrained(
    'bert-base-uncased',
    do_lower_case = True
    )
# Out:
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
df.data_type=='train'
# Out:
# id
# 1       True
# 2       True
# 3       True
# 4      False
# 5       True
#        ...
# 495    False
# 496     True
# 497     True
# 498    False
# 499     True
# Name: data_type, Length: 499, dtype: bool

# %%
df[df.data_type=='train']
# Out:
#                                                   text  category aspects  \
# id
# 1    Due to the situation created as a result of th...  Negative       I
# 2    During the lectures there were also various pr...  Positive       X
# 3    In general I can say that during this difficul...  Positive       M
# 5    The same process was followed in the Human-Com...   Neutral       L
# 6    But I can freely say that we have not had any ...  Positive       G
# ..                                                 ...       ...     ...
# 493  Our direction involves 90% of the work being d...  Positive       L
# 494  Evaluation-The evaluation part has been one of...  Positive       V
# 496  Learning - I personally think most students ha...  Positive       L
# 497  Replacement of the evaluation system in some c...   Neutral       M
# 499  Although I was not able to physically particip...  Positive       X
#
#      label data_type
# id
# 1        0     train
# 2        1     train
# 3        1     train
# 5        2     train
# 6        1     train
# ..     ...       ...
# 493      1     train
# 494      1     train
# 496      1     train
# 497      2     train
# 499      1     train
#
# [424 rows x 5 columns]

# %%
df[df.data_type=='train'].text.values
# Out:
# array(['Due to the situation created as a result of the pandemic, we, like most institutions in Kosovo, have been forced to attend online lectures',
#        'During the lectures there were also various projects from which we benefited a lot and these projects although from a distance I think have been quite useful',
#        'In general I can say that during this difficult period we have managed to successfully complete the online learning process',
#        'The same process was followed in the Human-Computer Interaction (HCI) course',
#        'But I can freely say that we have not had any setbacks in any aspect, because we have had support at all times from both the professor of the subject and the institution in general',
#        'Self-confidence when I started lecturing on Computer-Human Interaction was a positive belief',
#        'At first I was worried about how we would handle the quizzes, how we would engage during the lectures, since we were teaching online for safer health reasons',
#        'The reason for learning online was a pandemic and the decision not to hold lectures at university facilities',
#        'However, UBT was the first institution in the country to practice the online teaching method',
#        'There have been few obstacles and technical problems during the teaching development',
#        'I appreciate UBT as an institution that enabled us not to lag behind with lectures, as well as exams, but as part of this institution are all the staff who have done tireless and correct work',
#        'In HCI we have been engaged in projects and quizzes',
#        'It was obvious from the first lecture that the HCI course was a very attractive course',
#        'The projects we have done have been successful because in that way we have tried how to design a website, which we need as experience for the future.',
#        'Professor Krenare Pireva Nuci, with whom we gave the lectures, with her contribution has made the subject as attractive as possible and the way of teaching has been very level',
#        'Regarding the ambiguities not only during the lectures but also about the project, I did not hesitate at any time to ask questions to the professor, because I knew that he would not prejudice me about the questions, but would appreciate the interest in the subject',
#        'This year was characterized by the pandemic caused by the Covid-19 virus',
#        'The subject matter was very accurate',
#        'Even before starting the course, my impression of this course was good but there was a last minute change where we were informed that the course would be held online',
#        'As a computer science student who has already finished the 4th semester, I spent three more semesters but this 4th was different',
#        'The course "Computer-Human Interaction" in my opinion is very important, although it seems easy and implied by everyone in this course students can learn things they knew but not in so much detail then also gain complete knowledge of NEw',
#        'Computer-Human Interaction Course, in addition to being an important subject, was also a very attractive subject',
#        'In my opinion, holding online learning has been a very good experience for all of us',
#        'Course: In my opinion everything was fine, the course was easy to learn, the course chapters were important to better understand computer-human interactions one of my suggestions is to add even more prototype building exercises through Adobe XD',
#        'As a UBT student I am very pleased with the development of online learning during the Covid-19 pandemic',
#        'But if we stop at the subject I liked it a lot, because it was a very interesting subject it was not very monotonous in terms of theory',
#        'During the pandemic, online learning was something new, both for us and for you.',
#        'The part of the projects and quizzes has been as a test of our knowledge, especially the quizzes',
#        'If I were to grade it without a doubt you deserve 10',
#        'Our direction involves 90% of the work to be done on the computer, and I believe that this course has properly taught us human interaction with the computer',
#        'The teaching process due to pandemics was held online and in my opinion it was not a big handicap thanks to the professionalism of the professor and the staff of UBT that enabled the development of teaching at a very high quality level.',
#        'The professor was perfect for the subject and the class was quite qualitative and productive because there was constant interaction between students and the teacher through questions and answers',
#        'In the end it was also the part of the project that I personally think was the most important part because working on it, things became much clearer',
#        'Overall, I am very pleased with the way this course was conducted and I hope to continue at this pace in the other semesters as well.',
#        'During the quarantine I liked the way of teaching online organized by UBT, because within a short time it was necessary to find a solution in order to take care of health in the first place and not to be left behind with lessons as well',
#        'As a second year bachelor student, the subject "Computer-Human Interaction" has been a very understandable, competitive subject and has managed for a long time to develop my skills from zero to a higher level, in analysis , designing, developing and designing applications or websites through AdobeXD',
#        'What I have learned I have learned that although some things may seem easy and do not weigh on the user they are really important even though the details are quite small',
#        'Online learning in general did not have a very positive effect on me, but the HCI course was one of the only courses that was easier to understand but also more attractive than other courses',
#        'In terms of online learning everything was fine except in some cases we had a problem due to the large number of students, while in terms of the effectiveness of normal online learning was not as effective as it would be if those lands were physically maintained , but there has been no lack of effectiveness in online learning with the platforms offered by UBT.',
#        'The HCI course held this year was quite understandable and above all the interaction of students with the teacher during the lectures was maximal',
#        'I am satisfied with the process of learning online in the subject Computer-Human Interaction',
#        "As a second year bachelor student, the Human-Computer Interaction course has helped me a lot to understand what the user's intentions are, how the user can be affected, how he / she is perceived and many details of others that I have not paid any attention to before",
#        'I as a student of UBT am very satisfied in terms of online learning during quarantine time',
#        'Regarding the evaluation of the course, I must emphasize that it has been an attractive subject to learn, where I believe that most students, including me, have pushed us to research more about the interaction between computer and human, where the connection between the two it is essential to know and to understand',
#        'My opinion on the subject is that it was something new for me, very interesting things in 12 weeks, and this is something very good on my part, there were also parts that were both developed and very attractive with side of quizzes',
#        'The Computer-Human Interaction course is a highly aimed course in computer science for anyone aiming to see their future as a software engineer, this course provides an overview of how the design process of a product, and is one of the subjects I had the easiest distance learning',
#        'Given the situation we are in at the time of the pandemic, I think that the learning process has gone all right even though for us it has been a very big and new challenge',
#        'First of all, I am very glad that at least someone from the faculty takes care to get an opinion from the students because unfortunately many professors have not dealt much with this work.',
#        'Regarding the HCI subject, I do not know how I could have been the way of teaching at UBT, but since online everything was perfect on your part, for the final exam we did not even need to browse the lectures because everything was explained perfectly during the lectures, if I had the opportunity to grade HCI I would grade it',
#        'Regarding my opinion about the progress of the process of this case',
#        'In this semester, despite the changes and challenges we had, we tried to pass the course and acquire as much knowledge as possible.',
#        'The course we attended this semester HCI is one of the courses that I liked the most, and my interest was greater for this course as it was a course that attracted our interest and has a great impact on my profession in it future',
#        'During the last semester I had the good fortune to attend the course "Human Computer Interaction", but due to the Covid-19 pandemic we were forced to attend lectures online',
#        'In the following I want to give my opinion on the subject in question',
#        'Course - during this pandemic time the study material has not undergone any change, I think that keeping the courses online has had its own qualities due to the possibility of reviewing the lectures',
#        'First I want to start with an opinion about the subject for which it was so far on the list of most popular subjects',
#        'This course was very good for us as it enabled us to understand the connection between computer and human',
#        'Regarding the above questions about the evaluation of the subject, professor, exam and online lectures, everything was perfect starting from the online lessons we had where we also kept quizzes for an evaluation about the topics we have elaborated and have been at the level',
#        'Despite the situation in which the teaching process took place this semester, the structuring and organization of lectured topics as well as the progress of lectures on relevant topics has been quite effective resulting in achieving the competencies provided for the relevant subject',
#        'Online learning has been a new experience for me and I believe it was the same for other colleagues',
#        'Regarding my evaluation of the subject, exam, projects, evaluation, institution, and professor I can say that I have no objections to the subject',
#        'The development of online learning was a new experience in which we students and staff of professors passed',
#        'The online learning we practiced during the quarantine has been a different experience than we have had so far',
#        'Online learning has been something new for me but also for all students, at first it was stressful as new applications had to be used, but Ubt as an institution and the lecturer have provided us with a much needed support for the situation that we we feel as comfortable as possible during lectures',
#        'HCI course has been a very attractive course, full of new information from which I learned a lot',
#        'In the situation we were in due to the pandemic, even though we did not have the opportunity to teach objectively in the faculties, the teaching was quite effective.',
#        'At UBT branch "Computer Science and Engineering" online learning has been an interesting experience',
#        'I think the course was very necessary for us, because I got a lot of knowledge on computer interaction with humans and application design, I learned a lot of things that I did not even know at all',
#        'The HCI course was very understandable and useful, the lecturer was regular and her skills to explain to us were very clear',
#        'I hope everyone who reads this letter is in good health at this time of pandemic',
#        'In terms of online learning, I have personally been satisfied with both the lectures and the exercises',
#        'My evaluation of the subject: it is satisfactory, the subject itself was very attractive and we developed a lot of knowledge on this subject, the topics were very interesting and challenging',
#        'My opinion on the subject is quite positive, considering the active situation we are in.',
#        'Within this letter I have given my opinion regarding the evaluation of the subject, professor, projects, evaluation, institution and online learning experience during the quarantine period.',
#        'In general online learning has been well organized in terms of UBT staff, considering that it was the first time we are going through such a situation',
#        'Evaluation of the subject - to be honest, when I saw this subject in the second year syllabus, I did not think it would arouse any special interest.',
#        'Starting with the math that there is a huge number of students and there are only 2 teaching hours per week with the subject HCI, the course is not based only on project presentation, but on lectures and last week on project presentation, even someone who has not been never participating in this course, can conclude that it is impossible to present projects by all groups',
#        'Despite the pandemic situation and the obligation to take the course online, learning has been quite effective',
#        'I am a student of UBT from the academic year 2018-2019 and so far I have completed five semesters and during my studies at UBT I have learned many things and gained knowledge about many different topics related to my direction in Computer Science and engineering',
#        'During the course or online learning in this pandemic time I felt good about the flow of lectures and how the new information was understood',
#        'My experience in online learning has greatly influenced my views on teaching lessons',
#        'Enjoying the epithet of a student means being part of a journey that will capture many experiences, some more liked and some less, but in both cases we will be the beneficiaries of a life lesson',
#        'The quizzes were part of the syllabus which I think were very special part of this course',
#        'Lecturer-Form of lecturing- In such a subject, as much interactivity and cooperation, conversation and co-study are required',
#        'During my experience at the Faculty "UBT" as a student I met many professors / resha where each was different from the other, among them I had the pleasure to learn, I worked with one of the best professors Krenare Pireva-Nuci in the subject "HCI"',
#        'The subject - "Human Computer Interaction" is a subject that we need very much for the future, although we thought that we knew these things this subject has enabled us to understand things even better',
#        'As a subject it has been very influential in the way I see the interaction between man and computer and how I understand it',
#        'The most positive part is that the learning has continued and we did not have to go back to the beginning',
#        'The pandemic created a new reality',
#        'One of the most interesting and fascinating subjects over the years has been HCI (Human Computer Interaction) and has introduced us with new perspectives about the digital world that surrounds us in everyday life.',
#        'Also in this course we have learned many things where this knowledge obtained from this course we will need in our career',
#        '  I was convinced that maybe it would not go so well, that online learning would not be held properly',
#        '  I came to this university because it offers all the opportunities, which opportunity I do not miss even in the 4th semester to realize the online platform in the best possible way',
#        'I liked it because it took me a little away from thinking that Computer Science is just about coding.',
#        'Regarding the HCI course, lectured by prof',
#        'Professor: I think she was correct and taught the subject to its maximum',
#        'All subjects were taught with full accuracy and especially your subject Computer-Human Interaction, where the subject was very attractive and the professor was at the right level so that I passed miraculously even though the lesson was held at a distance',
#        'But for me personally online learning was not so convenient, it was a bit difficult to have the necessary concentration during an academic hour, because I think that physically learning is more understandable and we have an easier access to professor-student communication',
#        'I have come to understand better what is most important to users, what they want, their goals and requirements, how they are perceived and many other details that I have not paid attention to before.',
#        'What went well Almost everything went well, as we were forced to give online lectures due to the epidemiological situation at first I had my doubts about the effectiveness but in the end I was convinced that everything went well',
#        'The organization of the course was at the right level because in addition to explaining the lectures, the quizzes before and after the lecture had a very good effect as they forced me to focus on the lectures',
#        'A good feature about this subject were the quizzes at the beginning and end of the lecture because they forced you to be focused on the lecture all the time, also the part of the project was another very good feature because it makes assessment much easier in this subject, another thing that impressed me was the great variability of the project themes that you could choose as you wish',
#        'The holding of quizzes by the Proud Professor both at the beginning and at the end of the lecture have helped a lot in the better and faster understanding of the lecture and the subject in general',
#        'Because despite the very disturbing circumstances created during the beginning of the semester until the end, high quality teaching conditions were created both from the teaching side and from the technical side of the university.',
#        "I am now able to understand what users want, how easy it is to remember, what could be a more accurate design based on user requirements to honor a more accurate, easy-to-use design, easy to learn, easy to remember thanks to you for making our subject very attractive, easy, trying to involve each of us in debates, to give our opinion, where it's has helped even more the way of thinking by the user, who may have a variety of requirements, thoughts that need to be learned that the user should be at the center when building a design",
#        'Online learning has been at the best possible level',
#        'HCI has been a rewarding experience for me in terms of my development as a developer for technology and its relationships with people as we move forward, in a world increasingly driven by interactions with computers',
#        'While the way of explanation or presentation of the subject by the Professor, has been quite accessible, but in the future I would suggest to use easier terms to understand, as it would be easier and more accessible for us students',
#        "In terms of the professor's evaluation has been perfect with the subject, the connection with the students, the most conversations, the manner and opinions of many students has been the best point for a debate which we have done even though the whole period was during quarantine has been extremely well led, thanks also to the professor",
#        'As for the syllabus part of the course the App Inventor 2 part in my opinion has been old technology and in this respect we would probably find it easier to use React Native as examples of designing an application',
#        'In terms of course evaluation taking into account all the difficulties during this time, I think the lectures went well even though the interactivity and practical work were more difficult to accomplish virtually.',
#        'The way of speculating 10/10, The way you managed to then interact with students 10/10, The way you divided the project into two phases 10/10, The way the quizzes were held 10/10',
#        'I am satisfied with the professor and the subject',
#        'The lectures and the lecturer of the course, Professor Krenare, have been quite understandable',
#        'The topics were quite well explained and looked quite interesting, and the explanations from the professor of the subject were never lacking down to the smallest detail.',
#        'Regardless of the situation and circumstances, I can freely say that I have absorbed enough knowledge, and in my opinion, regardless of the distance and holding online lectures, the way the lecturer presented and holding quizzes in almost every lecture kept us active all the time and excited to hear something new, and to learn from what was presented to us',
#        'Subject in general- The subject in general has been very good, I have learned a lot about how to build a website or app, in order to be easy to use, clear, to represent the company properly, and be of good design',
#        'Professor - most professors have proven that they can teach online even in times of pandemic should keep students engaged with projects, questions, quizzes, questionnaires, etc.',
#        'While for the professor I have a great liking for the way the class is organized, to hold a class with her was a pleasure, this made her special attractiveness and the way she presented herself to the students',
#        'As far as the professor is concerned, the lectures have been very clear and we have done the practice of some programs that we have learned that have resulted in the best possible way in terms of practical teaching.',
#        'The factors that have influenced such an effectiveness are the very adequate preparation of the lecturer of the course, Professor Krenare Pireva Nuci, for the taught topics and the methodology used by the professor for the development of the lecture',
#        'Learning online as simple as it sounds was not the same when it came to its application but through different platforms it was easy to use',
#        'The structure of the subject and teaching was always at the level, you as a professor were always able to explain to us every possible detail by explaining it in the easiest way, always creating a very comfortable environment during the lessons',
#        'This situation was thankfully managed very well by both parties',
#        'As a start I believe we have all shared the same opinion that online learning will not be as effective as teaching in faculty facilities',
#        'The HCI course was very interesting, where I learned things that are very important to the real world but I just did not have such a perspective on the interaction between computer and human',
#        'The materials in the moodle as well as the book proposed by the professor have been quite voluminous and understandable',
#        'Where everything went adequately and nothing was missing during the course',
#        'The HCI course has had quite comprehensible, useful and necessary material for our direction',
#        'Lectures and exercises are held virtually through the moodle platform',
#        'The professor has been very level and there has been a lot of interaction between the professor and the student',
#        'The interest to approach this course was greater as the development of the course was very attractive, holding quizzes made us better understand the developing lecture and to result in excellent success',
#        'During this time of quarantine, respecting the decisions of the government for the best for us, we are obliged to keep learning online.',
#        'Learning online was a good opportunity for me because I did not need to travel to Prishtina, so it was possible for me to attend lectures from work or home, to start exams and lectures where I left them a few years ago , due to work and family care',
#        'Evaluation about the professor: In terms of evaluation around you I have no criticism only praise, you have been quite correct, attractive and very creative',
#        'During the development of the learning process through the online platform, which was somewhat different from the year we left behind, it is not that we encountered difficulties or misunderstandings about the subject',
#        'Specifically in terms of HCI lectures are conducted in a regular manner without obstacles or lack of any lectures or exercises',
#        'But from the first hour physically held in the premises of UBT, after the presentation of the syllabus of the course by Professor Krenare Pireva, the topics were extremely interesting, and described the most sensitive part of working on the computer, and all new technologies - how the user should evaluate some other features, before finalizing a product, or something else',
#        'Most students, unable to present the project during a lesson, have made a record of themselves with the idea and work they have done.',
#        'The professor of the subject Krenare Pireva was maximally committed to the most accurate distribution of the things we have learned during this semester, and has made the lesson so accessible by dividing it into quizzes, explanation of the lecture, and being very free with students, who made the subject attractive and made the students not miss the lecture',
#        'I think that this process has been adequately developed and there have been no lack of elements of interaction that usually develops in real teaching',
#        'The conditions offered by the college are good and most likely the best in the region where the campuses, literature, professors and courses offered by them are always out of date with modernizing all aspects and making it easier for us to study.',
#        'Given the direction (Computer Science) it was not so difficult to keep learning online, but above all the interest of professors and students has made everything go well',
#        'This semester was no different',
#        'Thanks to the tireless work of UBT staff, we have missed almost nothing during this period',
#        'The experience I went through and want to describe today includes a 5 month period of online lecturing / learning manifested by the indescribable commitment of the professors and their professionalism in the areas they teach for which I am very grateful.',
#        'They served as an aid to us as students, having the opportunity to test our knowledge and have an insight into where we are and how much we are benefiting from the HCI course',
#        'It means that we have used these methods consistently and I believe they have been very effective',
#        '  I want to describe today a 5 month period of online lecturing with her indescribable commitment',
#        'During this pandemic time learning online has been a bit difficult but however there have not been many changes which have affected not understanding the subject',
#        'Since we had a previous course with Professor Krenare, the progress of the class has been familiar to me and easy as before',
#        'We have gained experience related to the development of online learning',
#        'At the same time, Professor Krenare Pireva has done an excellent job of conveying the material to the students and I can say that it was one of the only subjects in which I felt energetic to participate.',
#        'We have learned that every application has a logic within itself on the part of the user',
#        '  When I started this university I knew it offered all the conditions and I hoped that online learning would be well maintained',
#        'Professor Krenare I think has been competent and has taught the subject to the maximum capacity of her skills, and I think that her effort is reflected in the ability of students who built group projects and thus revealed the creativity and lessons learned from the subject',
#        'This course is also why I am now interested in creating prototypes of Websites or even mobile applications',
#        'Krenare Pireva, I can say that the process of holding lectures has been at the right level and the methods chosen by the professor for engaging students have been welcomed by all (holding quizzes) and very effective',
#        "Projects: In my opinion the projects have been very important for this course, they have played a very big role in the understanding of the course and the development of students' skills",
#        'The evaluation of the course was very correct and through projects, through quizzes the subject became very easy to understand and very clear, we also had at the end the final exam which was compiled in a very correct way where I am shared very pleased',
#        'Regarding the subject Computer-Human Interaction has been quite attractive and accessible, the lecturer has always given the maximum in order to be as easy as possible for us',
#        'The course was held with maximum dedication by you, the lectures were compiled very clearly and understandably, where the inclusion of quizzes at the end of each lecture has made it possible for the course to be even more understandable, to have more clear the main points, to test ourselves on how focused we are and whether we have managed to understand the lecture at the right level as it should',
#        'But lo and behold the semester is over and everything is going well',
#        'What should I have done better? Because the lectures were in the morning sometimes I probably did not have maximum concentration in the lectures but I replaced them and watched them again',
#        'Also the part of the project was good, the topics of the project were good and related to the subject, also their defense was done in the most logical way possible',
#        'Demonstrations of exact examples have also helped a lot in the better understanding of this subject as was the case with finding information in the Tullis experiment',
#        'Here I can emphasize the correct and timely information for all the details related to the subject and the progress of the online learning process',
#        'This would be even more successful if they kept it physically in UBT facilities, enabling us a better communication with both colleagues and you',
#        'The evaluation of the course was in the right way, in which there were exams, projects, assignments and other quizzes',
#        'One of the main design aspects I had not considered before this course is the "intuition" aspect',
#        'The projects in my opinion have been well organized together, where it has encouraged group work among students, and has made each of the group members to be active in working and realizing the topic',
#        'Also the work of projects has been something very interesting to work with young students, to express the interests and ideas of all, it has gone so well even though something new has gone very well online and every week even more interesting has become',
#        'The evaluation part for translating a chapter seemed too much to me even though it aimed to motivate students to read more about the subject',
#        'During the lectures we were satisfied because we learned many new things that we will need further in the development of our profession',
#        'Due to the correctness it should be mentioned that the only thing that probably was not right is the way the exam monitor (ARBER KADRIU) was very arrogant with students, canceled many exams and many of them without any reason, such as I suggest that the exams you take should not be monitored by Arberi, because many students have lost the effort they have made in your subject',
#        'We learned a lot and the subject was very attractive',
#        'Also, the methods that have been used in the development of the learning process have made the class more attractive',
#        'Despite the fact that this semester took place online in the above-mentioned subject, we did not encounter any difficulties, both technically and in terms of explanation or understanding by the students.',
#        'Working with the projects was a bit difficult, as they were group projects, but thankfully using the existing tools and holding â€œmeetingsâ€\x9d with the group members we managed to complete the work on the projects.',
#        'Professor:) - Always with a clear explanation (I have no remarks)',
#        'Projects - have been one of the most engaging parts of this time where even though we have had a large number of projects in a short time I think they have helped the progress of teaching by professors',
#        'The projects assigned by the professor were very correct',
#        'Throughout the semester the Proud Professor has tried with various methods to keep us active during the class, talking together and taking into account our opinion, answering our questions without hesitation and also something that I think has been very effective and also made us remember more the things we learned were quizzes, which included the most important information we need to keep in mind from a learned topic, also the quizzes helped us even at the end for the exam too',
#        'The projects we had were very good as they prepared us for the lectures that would be held throughout the online learning process, which made the learning even easier as we had already started elaborating the subject through the projects.',
#        'In my opinion I would say that this way of learning online has been productive and accurate',
#        'Professor-student interaction has been two-dimensional because in addition to communication and continuous discussion during the lecture, where we are involved by the professor in sharing our opinions and attitudes on certain topics and issues, quizzes are organized before and after the lecture, which which influenced the obtaining a clearer picture of the level to which competencies have been achieved, initially for specific topics and as a derivative of it for the subject in general',
#        'My experience with online learning was good and I liked it a lot, normally it does not replace the regular traditional learning but even this had its benefits',
#        'And you were always ready to change our conceptual thinking, placing us in the future, as professionals of this subject',
#        'At first the acclimatization was a bit more difficult with the new learning platforms but then everything was easy and understandable',
#        'On the contrary the professors have done an excellent job in terms of teaching and not to be left behind with lectures and exercises',
#        "The most difficult task of a professor is to motivate students to learn, but perhaps the lecturer's love for the subject was reflected in us, where during the process we had various commitments and tasks such as tests at the end of the lecture and projects where we have been active all the time, in terms of evaluation I believe that everything will be fine as the professor has been open to communication",
#        'Also the interaction of the professor with students has influenced the subject to be understood more easily and pushed us to read with chalk to be more successful in the quizzes we have kept',
#        'Although the problems have been external factors such as: internet breakdown, power outages, etc.',
#        'Also, I can say that it has been one of the subjects that has gone best online, and also Professor Krenare has greatly influenced the increase in concentration per hour all the time',
#        'In the course Computer-Human Interaction with the PhD professor',
#        'Quizzes have been a great form of keeping students active',
#        'Also the projects and the final exam were ok and I did not encounter any problems',
#        'All I needed now to attend the lectures, exercises, consultations and exams, was a mobile computer, and from it, I was given the opportunity to listen to the lecture, to ask the professor about something I did not understand, and in the same time, I did not lose my job and also saved time for family',
#        'What impressed me the most is the way you managed the course and the way you approached the students which was quite professional which we have not encountered in other professors',
#        "Professor's evaluation: Krenare Pireve was an excellent professor, she engaged us every time even though we were in quarantine, she gave excellent lectures",
#        'From the questionnaires we had in the project request, we received opinions from members of other projects, about our projects and vice versa - we gave our opinion on their projects',
#        'We conducted the fourth semester online through the BigBlueButton platform and it was generally ok but sometimes with minor technical problems which were fixed in time and we did not encounter the following',
#        'It is understandable that learning is traditionally more efficient in terms of student concentration, but online learning has had advantages given that most students have to travel, which was not possible during the pandemic',
#        'The creation of an integrated system has facilitated the work of us students and professors to act even in pandemic times through internet technology, online and virtually, from any place and at any time',
#        'We started the first lecture in the course Computer-Human Interaction on the UBT campus, not knowing that it will be the only lecture of this course that will be held physically',
#        'Another very popular part of me was creating prototypes through various applications',
#        'Also, I did not experience any monotony because the lecture techniques were of different forms',
#        'Projects - have been one of the most engaging parts of this time where even though we have had a large number of projects in a short time I think they have helped the progress of teaching by professors',
#        'Considering the situation we are in, fatigue, monotony has never been seen of the professor, that in the first hour until the last hour the motive to learn a few smiles during the class did not fall on the clock making it more attractive and making us made even more interested in the subject',
#        'I think this course has been successful, the way of teaching has been very good, since holding the lecture interactively and finishing it with quizzes, has been a very effective way of learning',
#        'Familiarity with new programs, programming languages â€‹â€‹with which they are developed',
#        'Online learning has been one of the best learning experiences because I have had the opportunity to always listen to lectures on time without having the opportunity to miss',
#        '  I think online learning is the right thing to do at this time as the course itself talks about the computer-human interaction we were having each week with the subject teacher which shows us how it interacts even if we are not physically in the classroom.',
#        'In general, Professor Krenare Pireva was more than prepared every hour and used many techniques which made the lesson more interesting.',
#        'The professor has always been prepared in lectures and has developed the lecture interactively',
#        'Assessment: I think it was correct and fair',
#        'Although in bad conditions the UBT staff in the best way has managed to keep learning by teaching us many things, as well as giving us a very good experience for our lives',
#        'The project given by the lecturer was a challenge for me and left a good impression on me',
#        'Also the part of filling out the forms has been a very good form, allowing us to express our opinion about any problem or ambiguity about the class or quizzes held, which also shows the great care of the professor towards the students',
#        'Regarding the course "Computer-Human Interaction (HCI)" in general I did not have any remarks, the course was held with maximum dedication by Professor Krenare Pireva, who had compiled the lectures very clearly and understandably, where in addition to lectures tried to make the subject even more understandable through quizzes which were also very clear',
#        'The project part is a key part of the course, because in a way it is the application of the knowledge we learn in this course',
#        'With their help and dedication, everything was easier and very efficient in terms of the progress of the class process, thus being able to all join the schedule without any major problems and continue learning as it was in normal conditions.',
#        'As the communication part has been more difficult as far as the project part as we needed consultations in order to better understand what we need to detail more',
#        'Each of these is developed, and then the course evaluation can be done',
#        'That is, good design should be something that a user can understand, easily access, and feel confident in a successful outcome without doing too much work in understanding the complexity of the design.',
#        'As for her assessment, it is a good way that we have been engaged with miniTests where they have helped us to be more vigilant in lectures, while the way of presenting the exam has been in order.',
#        'Regarding the evaluation of the professor, I am very satisfied both in terms of lecturing and in terms of engaging with projects and quizzes which we have kept during the lectures, and have helped me immensely in the final exam',
#        'First of all, quizzes have helped us to be more focused on lectures',
#        'As a student I had my doubts about the form of organizing online learning, from the difficulties we might encounter, but everything went well I can even say that I liked this form and found it even more interesting to attend lectures',
#        'But in case of small mistakes or delays, I hope there will be consideration for us',
#        'Projects- Although the subject and direction in general aim to bring students closer so that they get used to working in groups, I still prefer these projects to be done individually, in order to show the creativity and knowledge of each individual.',
#        'Evaluation - has not undergone any major change during the pandemic The only thing I think was the fact that the evaluation was done online for change from other times',
#        'As for the way of evaluation, I believe that it is the ideal way and you should take it as a model for other subjects as well, because that way keeps us as students all the time active, which is a great thing.',
#        'Regarding the organization of the course and how the classes were held in this course I do not have any remarks or criticism',
#        'What I liked most was the Quiz section, which helped us understand the key parts of each lecture and enabled us to remember the most important things more easily.',
#        'In the end I would have no problem continuing again in this form',
#        'Online learning - Due to the conditions we are in, we were forced to keep the HCI course on online platforms, which turned out to be quite successful',
#        'The evaluation of the course I think was right because it kept us engaged with the course material through projects and quizzes that were organized during the class',
#        'Krenare Pireva online learning, lectures and assessment were appropriate because we had 5 quizzes through the kahoot platform which enabled us to be active in any lectures and listen to the professor attentively!',
#        'Projects have been a very good way of practicing the knowledge gained in practice',
#        'The online learning process was developed in a regular way, it was a new experience for us students, but it was very well managed by the UBT staff and teachers',
#        'The evaluation as well as the curriculum of the course organized by the professor has been appropriate and very attractive with quizzes and the project done',
#        'So far I have no objections regarding the institution, the professor and the evaluation of the course',
#        'Evaluation about projects: In terms of projects I think it is very helpful to have the opportunity to work together to exchange our ideas with each other, but I think that individual projects should be left space to have the opportunity to fully display our work since in groups it often happens that they do not work equally',
#        'During the development of online classes from the HCI course, I felt very good, the course was always at the best possible level, and the participation was very willing because all students had the right to speak to be as active as possible.',
#        'The evaluation in this course is quite structured and divided into different parts for each activity I did, the evaluation was: very good',
#        'The subject Human-Computer Interaction had a positive effect on our psyche, I even think it would be fairer if this subject would be moved to earlier semesters, so that students become familiar with the direction they have chosen, and feel the warmth that this the subject reflects on us',
#        'For as many projects as I have seen, in my opinion they have been very good, always starting from the fact that we are learning, and how we have gotten the legs yet to do something â€˜wowâ€™',
#        'The assessment is quite correct because each job we did had the right percentage based on how much we had to work and learn',
#        'interruption of electricity supply in settlements, temporary interruption or internet disruption, etc.',
#        'We also owe it to the professor who has always kept the class attractive and interesting despite the difficulties',
#        'From conventional to digital lecturing',
#        '  The opportunity to be in constant communication with professors and the comfort to express oneself more easily was much needed.',
#        'I am introduced to the subject by the professor leaving an appointment for next week',
#        'Learning what a prototype is, low-precision prototypes, high-precision prototypes, and finally their presentation',
#        'Efficiency - Through your work you have been efficient, enabling us to better understand the essence of the subject, and you have opened the way for us to self-engage and analyze different techniques and programs',
#        'Each time the professor started the class in a regular way, she was very clear in explaining the subject and we were in interactivity with the professor, asking questions via chat message, or even conversation.',
#        'Proud Professor has proven this, and her effort reflects on the knowledge and ability of the students',
#        'Projects have also played an important role in the even better understanding of the subject',
#        'I had heard about the development of online learning, but had never taught online',
#        'One of the things that has caught my attention from the beginning is the way the professor has interacted with the students, and made the learning development process interactive.',
#        'Professor',
#        '  Online learning in my experience has been better than physical lectures',
#        'When I started this course I thought about how the course would be organized and how the professor would interact with us',
#        'The rating is fairly divided in my opinion',
#        'Project development has been one of my favorite parts, because in addition to the theory which has its importance, we had the opportunity to work with a new application and develop a new experience',
#        "And it's also worth mentioning the way the assessment was appropriate and especially the part with Kahoot that was as relaxing if I could express it and that helped me learn more easily",
#        'The project has been my favorite part and the limitation of the project topics has made us more creative in what is assigned to us, it has raised our awareness and we have had the opportunity to research more about that.',
#        'Often simple things from the outside have great importance and key role in building a software or whatever else human-computer interaction is done through it',
# ...
#        'If I had thought about teaching online some time ago, it would have seemed absurd, but I tried and proved the opposite because UBT organizes online teaching in an excellent way together with its staff and professors.',
#        'But in general I am satisfied with the knowledge I have received in this subject and also with the Professor who has always been very prepared to hold the class',
#        'This assessment seemed very apt to me because it kept us students very active during the lecture',
#        'The only problem that arose from time to time was the problem with the network, where there were interruptions of lectures which were held through the BigBlueButton platform.',
#        'Of course, the lecturer has been at the level, making the subject even easier and more accessible',
#        'But this is just my individual opinion',
#        'Also the projects in groups until the final exam were in order, I did not encounter any problems, we were always informed in time for the submission of assignments, presentations, as well as for holding the exams',
#        '  In my opinion, the subject was quite interesting and not at all difficult to understand and learn',
#        'I also liked the way the quizzes were held in Kahoot because it was a real evaluation',
#        'The project we had about the subject with the help of the professor we did not have any difficulties at all, because about any ambiguity reached through emails we understood the ambiguities',
#        'And finally, Professor Krenare I think has given her best to make the watch as attractive and interesting as possible, which has been done very successfully!',
#        'Evaluation in general in the online way I think there is a very high possibility of abuse by students, and the results I believe are not realistic, while attending online courses, if there is will from the student I believe can be very effective, but I have a Complaints for some professors who did not set the exercises or lectures recorded, because often due to reasons such as electricity I was unable to follow the exercises and for that reason I had a delay in the grade',
#        'Online lectures, exercises, homework assignments, project presentations, exams were up to date and we were always informed in a timely manner about everything, about submitting assignments, presenting, taking the exam, replacing lost hours and keeping e minitestev',
#        'Evaluation about the institution: I think it is an institution that offers satisfactory services',
#        'The distribution around the evaluations was perfect, we were always engaged in projects and quizzes, where this active participation facilitated the completion of the final test, and the distribution of points was very reasonable and accurate',
#        'Online learning is an effective method for this subject',
#        'For the way of evaluation we have not yet received a final email for our results but we are hoping that with these activities that we have developed together with the professor during this semester every student will be satisfied with the results obtained and the professor with our work',
#        'Krenare Pireva, from the subject of the first semester, IT law and society, unfortunately, for me this was the first time I attended a course with her',
#        'Assessment - the assessment method decided by the professor, it is definitely well thought out and appropriate',
#        'Pireva, which I think has positively influenced the reinforcement of this topic',
#        'As a start, we are informed exactly what we will elaborate throughout the semester, how the evaluation will be divided and how the final evaluation will be calculated.',
#        'This difficulty was only temporary and transient, also this challenge is further alleviated when you are a student of a university such as UBT, which manages the situation created by the virus in the best and most professional way possible.',
#        'However, this does not mean that I am against doing homework online or anything like that; i just like lectures to be held in a classroom',
#        'For any ambiguity, it was the professor who guided us tirelessly demonstrating each piece',
#        'You have also been interactive and really helpful in lectures in terms of questions-ambiguities',
#        'The project was also part of the sylbabus which has been a good experience and an experience with Adobe XD preparing us for further if we will have to work so for the future at work',
#        'Difficulty of adapting to online learning through the new platform',
#        'With this decision he offered us to be up to date',
#        'Everything took place easily and smoothly, very interactive and fun',
#        'She has used many different examples where with these examples the professor has made the subject very clear',
#        '  The lesson was very attractive because we kept continuous quizzes where we were given the opportunity to see how we are with the subject',
#        'I want to add that even though we did not have physical contact we could write to the professor by email and she did not miss her answers',
#        'But I have a suggestion, I think that within the course to include more tutorials about using different applications such as Adobe XD, App Inventor, etc.',
#        'The possibility of copying during the exams has been very high, which results in unrealistic assessment, therefore, if there is a possibility that the next semester will be held online, I think that greater measures should be taken during the exams.',
#        'But based on the circumstances of holding this course online and not in university facilities we have encountered many problems starting from the technical ones, there are still places where we live where the electricity stops',
#        'In my opinion, all this has made the evaluation part more manageable and more accurate',
#        'Also the different ways of asking questions like single-choice question, multiple-choice question or completing sentences in my experience have made the test more interesting, dynamic and more enjoyable',
#        '(I would suggest to all teachers this method of assessment in terms of part of the quiz)',
#        'Through projects we have learned how to design an application using different prototypes, to be as attractive, usable, effective, easy to learn how to use as well as tolerant of errors during use',
#        'The evaluation process was fair as it involved both our performance in the exam and the project, evaluating us in many ways',
#        's sitting in a chair for a while during the computer has caused weak eyes, as well as problems with the network or system, etc.',
#        'Hope to see you soon on campus facilities and continue in the same way we have been',
#        'As an institution UBT has managed the situation well and we as students have managed to attend lectures in real time and in a very correct way',
#        'In terms of assessment, in the first year I had the good fortune to attend another course at the professor in question, so I do not doubt its correctness or evaluation of the course as it has always been as transparent as possible to us.',
#        'Instituconi- I have no opinion',
#        'The material for the study was abundant and of different forms such as videos, online lectures through moodle, various books, etc.',
#        'UBT always tries to do the best for its students, in this pandemic time the reaction of the institution was fast and we immediately started teaching online, which helped us not to waste too much time and lectures',
#        'Therefore, I conclude that in this case specifically there were no serious barriers that would negatively affect the acquisition of organized online course',
#        'Projects have been a very important detail because they allowed us to apply the things we learned in lectures directly to our projects, allowing us to crystallize even more the information received',
#        'The lectures we attended were explained very clearly and in case of any ambiguity we asked the professor and received the necessary answer and clarifications.',
#        'The project-course was also organized in group projects, where the requirements were quite clear from the professor and the group work was very effective because by researching we learned many new things',
#        'Evaluation about online learning: Of course at the beginning it was a challenge due to technical problems, but the adaptation period did not take long',
#        'Important as always remains prof',
#        'It is not that I was so surprised by her lecture, because from the beginning of my studies I only heard words of praise for her',
#        '  The part that impressed me the most was the chapter prepared by us; indeed in addition to reading that chapter, we understood and interpreted it to other students, it really was the key point that encouraged us to continue with the other chapters to read',
#        'The communication part was also correct, where we received a response in case we asked questions about the project of the case',
#        'For this course we had two projects which were divided into two time periods and we had more than enough time to submit and the problems encountered during the work of these projects we discussed with the professor of the course and we have find a solution that suits our problem',
#        'The quick response of the university that enabled the lectures on the Big Blue Button platform, enabled us students not to lose the time and interest that comes to us at the beginning of each semester',
#        'Unfortunately, because of the time we live in now, online learning is becoming more and more of a necessity if we are to continue to learn the things we learn in the classroom.',
#        'Now as a student I realized that holding online lectures was not much different compared to physically held lectures, all thanks to the professionalism of our professor who has made this journey very easy and convenient for us.',
#        'The experience I gained as a sophomore in the HCI course will be a very special and at the same time very profitable experience for me and other students',
#        'Maybe, I would have a little remark to reply to the e-mail, or reply faster!',
#        'The exam was also ok everything was questions we talked about in lectures, in literature',
#        'Institution - In my opinion the institution has done a good job during the pandemic, this shows that the staff is serious and are determined to raise this institution as high as possible',
#        'Inability to evaluate the activity and participation',
#        'Because if we could not attend the lectures and take the exams we would be lagging behind for later goals in life',
#        'The projects have been very challenging and have simulated our creativity, making us pay attention to what is being created in order to give a well-realized product.',
#        'Projects and evaluation',
#        '  If in the quiz at the beginning of the class we did not succeed, in the quiz at the end of the class we definitely succeeded',
#        '  My best and most specific experience was the group work for prototyping with other students where even though they were at a distance there was no lack of communication and discussion about the topic we had chosen for the project which was the interface',
#        'as it seemed to me that the interest in subjects from other students was greater during the holding of these tutorials',
#        'In this letter we were asked to give our opinion about the evaluation, but we have not yet received information on how we were evaluated for the HCI case.',
#        'The improper functioning of the internet has made the communication part with colleagues as well as with you very difficult and I think that this would be more successful if we were physically in the facilities of UBT and to discuss together the issue of project requirements and design and to better express what we wanted to do',
#        'In a word, based on the circumstances of holding this course online and not on university facilities, for me it was also a motive to continue until the end of the semester with great dedication to complete this course',
#        'As for the evaluation part also because it includes exact percentages for each part of the subject I mentioned before and the benefits that each of them bring to the memorization and understanding of the subject, I am quite satisfied with the way we are evaluated',
#        'As for the projects and the exam, everything went smoothly and effectively',
#        'Unfortunately, due to the pandemic situation around the world it was impossible to attend classes physically, so lessons continued online',
#        'Overall I think it is a positive experience',
#        ', students, always, and it went so well that we were all for each other even though they were all online I did not feel anything unclear, except the lack of being live again',
#        'I do not think that the online medium has achieved the same results and effect, it has its shortcomings',
#        'Online learning was a very good and interesting experience for the students and the effort of the professors was maximum to provide us with the most accurate explanations, not forgetting the faculty who took care that the technical problems were minimal and we all felt how better during this period',
#        'The online learning experience was a very interesting experience that made us develop even more the ability to learn without real presence in the classroom',
#        'We have also had the opportunity whenever we want to access Moodle, where all the lectures we have given are located.',
#        'The topics have been quite challenging and at the same time attractive',
#        'There was not even a serious barrier around the HCI case, as in the other cases',
#        'This form of learning affects time management especially for students living further away from campus (avoiding travel)',
#        'of the subject where it was always understandable and found the best possible way of conversation with all students without exception',
#        "I also watched some interviews on television, and I feel lucky to have had the opportunity to attend the professor's lectures",
#        'Evaluation of the institution - for now UBT is the most appropriate and appropriate institution for continuing higher education',
#        'The online exam worked properly and I have no objections in that regard either',
#        'These projects, in addition to helping us learn the practical side of the subject, have also taught us the theoretical part.',
#        'Also, I think that due to new updates in technology, online learning will be much more prevalent even after this pandemic is over',
#        'Each lecture started in the right way, first with the professor greeting the students, opening the slides and starting the lecture in a very accessible, professional and special way.',
#        'Our direction involves 90% of the work being done on the computer, and I believe this course has taught us the proper human-computer interaction, being able to analyze user interfaces, user experiences, interaction design, cognitive aspects and virtual reality',
#        'Evaluation-The evaluation part has been one of the best I have had the opportunity to have',
#        'Learning - I personally think most students have had difficulty learning because this is the first time something like this pandemic has happened, but still learning in these periods is much easier for those who find a way to structure the days of and time for studies',
#        'Replacement of the evaluation system in some cases',
#        'Although I was not able to physically participate in the final part of the project presentation, I was satisfied with the way this whole process went.'],
#       dtype=object)

# %% [markdown]
# #We have to encode the texts by using tokenizer.batch_encode_plus

# %%
encoded_data_train = tokenizer.batch_encode_plus(
    df[df.data_type=='train'].text.values,
    add_special_tokens=True,
    return_attention_mask=True,
    #pad_to_max_length=True,
    padding=True,
    truncation=True,
    max_length=256,
    return_tensors='pt'
)

# %%
encoded_data_val = tokenizer.batch_encode_plus(
    df[df.data_type=='val'].text.values,
    add_special_tokens=True,
    return_attention_mask=True,
   # pad_to_max_length=True,
    padding=True,
    truncation=True,
    max_length=256,
    return_tensors='pt'
)

# %%
#For the train

# %%
input_ids_train = encoded_data_train['input_ids']
attention_masks_train = encoded_data_train['attention_mask']
labels_train = torch.tensor(df[df.data_type=='train'].label.values)

# %%
#for the validation
input_ids_val = encoded_data_val['input_ids']
attention_masks_val = encoded_data_val['attention_mask']
labels_val = torch.tensor(df[df.data_type=='val'].label.values)

# %%
dataset_train = TensorDataset(
    input_ids_train,
    attention_masks_train,
    labels_train
)

# %%
dataset_val = TensorDataset(input_ids_val,
                            attention_masks_val,
                            labels_val
)

# %%
len(dataset_train)
# Out:
# 424

# %%
len(dataset_val)
# Out:
# 75

# %% [markdown]
# ## Task 5: Setting up BERT Pretrained Model

# %%
from transformers import BertForSequenceClassification

# %%
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', 
     num_labels=len(label_dict),
     output_attentions=False,
     output_hidden_states=False)
# Out:
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ## Task 6: Creating Data Loaders

# %%
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler

# %%
#In Google Colab -- GPU Instance (k80)
#batch_size =32
#epoch =10

# %%
#batch_size = 4 #32
batch_size = 32
dataloader_train = DataLoader(
    dataset_train,
    sampler=RandomSampler(dataset_train),
    batch_size=batch_size
)

# %%
dataloader_val = DataLoader(
    dataset_val,
    sampler=SequentialSampler(dataset_val),
    batch_size=batch_size 
)

# %% [markdown]
# ## Task 7: Setting Up Optimizer and Scheduler

# %%
from transformers import AdamW, get_linear_schedule_with_warmup

# %%
optimizer = AdamW(
    model.parameters(),
    lr=1e-5, #2e-5 > 5e-5
    eps=1e-8
)
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,

# %%
#epochs = 10
epochs = 20

scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=0,
        num_training_steps=len(dataloader_train)*epochs
)

# %% [markdown]
# ## Task 8: Defining our Performance Metrics

# %% [markdown]
# Accuracy metric approach originally used in accuracy function in [this tutorial](https://mccormickml.com/2019/07/22/BERT-fine-tuning/#41-bertforsequenceclassification).

# %%
import numpy as np

# %%
from sklearn.metrics import f1_score

# %%
#preds=[0.9 0.05 0.05 0 0 0]
#preds = [1 0 0 0 0]

# %%
def f1_score_func(preds, labels):
    preds_flat = np.argmax(preds, axis =1 ).flatten()
    labels_flat = labels.flatten()
    return f1_score(labels_flat, preds_flat, average='weighted')

# %%
def accuracy_per_class(preds, labels):
    label_dict_inverse={v: k for k, v in label_dict.items()}
    preds_flat = np.argmax(preds, axis =1 ).flatten()
    labels_flat = labels.flatten()
    
    for label in np.unique(labels_flat):
        y_pred = preds_flat[labels_flat== label]
        y_true = labels_flat[labels_flat== label]
        print(f'Class:{label_dict_inverse[label]}')
        print(f'Accuracy:{len(y_pred[y_pred==label])}/{len(y_true)}\n')

# %% [markdown]
# ## Task 9: Creating our Training Loop

# %% [markdown]
# Approach adapted from an older version of HuggingFace's `run_glue.py` script. Accessible [here](https://github.com/huggingface/transformers/blob/5bfcd0485ece086ebcbed2d008813037968a9e58/examples/run_glue.py#L128).

# %%
import random

seed_val = 17
random.seed(seed_val)
np.random.seed(seed_val)
torch.manual_seed(seed_val)
torch.cuda.manual_seed_all(seed_val)

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)
print(device)
# Out:
# cuda

# %%
def evaluate(dataloader_val):
    model.eval()
    loss_val_total = 0
    predictions, true_vals = [], []
    for batch in tqdm(dataloader_val):
        batch = tuple(b.to(device) for b in batch)
        inputs = {'input_ids':      batch[0],
                  'attention_mask': batch[1],
                  'labels':         batch[2],
                 }

        with torch.no_grad():        
            outputs = model(**inputs)
            
        loss = outputs[0]
        logits = outputs[1]
        loss_val_total += loss.item()

        logits = logits.detach().cpu().numpy()
        label_ids = inputs['labels'].cpu().numpy()
        predictions.append(logits)
        true_vals.append(label_ids)
    
    loss_val_avg = loss_val_total/len(dataloader_val) 
    
    predictions = np.concatenate(predictions, axis=0)
    true_vals = np.concatenate(true_vals, axis=0)
            
    return loss_val_avg, predictions, true_vals

# %%
for epoch in tqdm(range(1, epochs+1)):
    
    model.train()
    
    loss_train_total = 0
    
    progress_bar = tqdm(dataloader_train, 
                        desc='Epoch {:1d}'.format(epoch),
                        leave=False,
                        disable=False)
    for batch in progress_bar:
        model.zero_grad()
        batch = tuple(b.to(device) for b in batch)
        inputs ={
            'input_ids'    :batch[0],
            'attention_mask':batch[1],
            'labels'        :batch[2]
        }
        outputs = model(**inputs)
        loss = outputs[0]
        loss_train_total += loss.item()
        loss.backward()
    
        torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
        optimizer.step()
        scheduler.step()
        progress_bar.set_postfix(
            {'training_loss': '{:.3f}'.format(loss.item()/len(batch))})
        
    #torch.save(model.state_dict(),f'Models/BERT_ft_epoch{epoch}.model')
    tqdm.write('\nEpoch {epoch}')
    
    loss_train_avg= loss_train_total/len(dataloader_train)
    tqdm.write(f'Training loss:{loss_train_avg}')
    
    val_loss, predictions, true_vals = evaluate(dataloader_val)
    val_f1= f1_score_func(predictions,true_vals)
    tqdm.write(f'Validation{val_loss}')
    tqdm.write(f'F1 Score (weigthed): {val_f1}')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch 1:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.34141683152743746
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 2:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.32854760544640677
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 3:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.32962250390223097
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 4:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.34935056418180466
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 5:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.34564123089824406
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 6:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.3334569473351751
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 7:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.34758536517620087
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 8:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.34347767915044514
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 9:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.3635263911315373
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 10:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.3674752062984875
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 11:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.3572176066892488
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 12:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.3593690405998911
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 13:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.36033071151801516
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 14:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.3575886913708278
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 15:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.37047203310898374
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 16:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.37936475766556604
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 17:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.3625935933419636
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 18:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.35452394826071604
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 19:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.35392498650721144
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975
# Epoch 20:   0%|          | 0/14 [00:00<?, ?it/s]
# Epoch {epoch}
# Training loss:0.37168475666216444
#   0%|          | 0/3 [00:00<?, ?it/s]
# Validation0.8269752462704977
# F1 Score (weigthed): 0.7176393976393975

# %%
#torch.save(model.state_dict(),f'Models/BERT_ft_epoch{epoch}.model')  
torch.save(model.state_dict(),f'/content/sample_data/Models/BERT_ft_epoch{epoch}.model')

# %%
## https://ruslanmv.com/blog/Deep-Learning-using-BERT-and-Pytorch

# %% [markdown]
# ## Task 10: Loading and Evaluating our Model

# %%
model = BertForSequenceClassification.from_pretrained("bert-base-uncased",
                                                      num_labels=len(label_dict),
                                                      output_attentions=False,
                                                      output_hidden_states=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=len(label_dict),
    output_attentions=False,
    output_hidden_states=False)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
len(label_dict)
# Out:
# 3

# %%
# Print model's state_dict
print("Model's state_dict:")
for param_tensor in model.state_dict():
    print(param_tensor, "\t", model.state_dict()[param_tensor].size())
# Out:
# Model's state_dict:
# bert.embeddings.position_ids 	 torch.Size([1, 512])
# bert.embeddings.word_embeddings.weight 	 torch.Size([30522, 768])
# bert.embeddings.position_embeddings.weight 	 torch.Size([512, 768])
# bert.embeddings.token_type_embeddings.weight 	 torch.Size([2, 768])
# bert.embeddings.LayerNorm.weight 	 torch.Size([768])
# bert.embeddings.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.0.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.0.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.0.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.0.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.0.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.0.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.0.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.0.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.0.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.0.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.0.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.0.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.0.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.0.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.1.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.1.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.1.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.1.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.1.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.1.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.1.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.1.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.1.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.1.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.1.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.1.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.1.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.1.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.2.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.2.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.2.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.2.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.2.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.2.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.2.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.2.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.2.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.2.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.2.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.2.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.2.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.2.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.3.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.3.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.3.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.3.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.3.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.3.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.3.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.3.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.3.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.3.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.3.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.3.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.3.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.3.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.4.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.4.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.4.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.4.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.4.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.4.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.4.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.4.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.4.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.4.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.4.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.4.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.4.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.4.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.5.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.5.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.5.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.5.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.5.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.5.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.5.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.5.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.5.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.5.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.5.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.5.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.5.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.5.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.6.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.6.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.6.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.6.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.6.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.6.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.6.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.6.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.6.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.6.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.6.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.6.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.6.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.6.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.6.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.6.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.7.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.7.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.7.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.7.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.7.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.7.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.7.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.7.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.7.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.7.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.7.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.7.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.7.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.7.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.7.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.7.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.8.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.8.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.8.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.8.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.8.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.8.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.8.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.8.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.8.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.8.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.8.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.8.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.8.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.8.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.8.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.8.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.9.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.9.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.9.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.9.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.9.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.9.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.9.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.9.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.9.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.9.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.9.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.9.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.9.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.9.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.9.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.9.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.10.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.10.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.10.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.10.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.10.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.10.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.10.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.10.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.10.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.10.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.10.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.10.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.10.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.10.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.10.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.10.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.11.attention.self.query.weight 	 torch.Size([768, 768])
# bert.encoder.layer.11.attention.self.query.bias 	 torch.Size([768])
# bert.encoder.layer.11.attention.self.key.weight 	 torch.Size([768, 768])
# bert.encoder.layer.11.attention.self.key.bias 	 torch.Size([768])
# bert.encoder.layer.11.attention.self.value.weight 	 torch.Size([768, 768])
# bert.encoder.layer.11.attention.self.value.bias 	 torch.Size([768])
# bert.encoder.layer.11.attention.output.dense.weight 	 torch.Size([768, 768])
# bert.encoder.layer.11.attention.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.11.attention.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.11.attention.output.LayerNorm.bias 	 torch.Size([768])
# bert.encoder.layer.11.intermediate.dense.weight 	 torch.Size([3072, 768])
# bert.encoder.layer.11.intermediate.dense.bias 	 torch.Size([3072])
# bert.encoder.layer.11.output.dense.weight 	 torch.Size([768, 3072])
# bert.encoder.layer.11.output.dense.bias 	 torch.Size([768])
# bert.encoder.layer.11.output.LayerNorm.weight 	 torch.Size([768])
# bert.encoder.layer.11.output.LayerNorm.bias 	 torch.Size([768])
# bert.pooler.dense.weight 	 torch.Size([768, 768])
# bert.pooler.dense.bias 	 torch.Size([768])
# classifier.weight 	 torch.Size([3, 768])
# classifier.bias 	 torch.Size([3])

# %%
# Print optimizer's state_dict
#print("Optimizer's state_dict:")
#for var_name in optimizer.state_dict():
#    print(var_name, "\t", optimizer.state_dict()[var_name])

# %%
device = torch.device('cuda')
pass

# %%
model.to(device)
pass
# Make sure to call input = input.to(device) on any input tensors that you feed to the model

# %%
PATH='./content/sample_data/Models/BERT_ft_epoch20.model'

# %%
model.load_state_dict(
    torch.load('/content/sample_data/Models/BERT_ft_epoch20.model',
    map_location=torch.device('cpu')))
# Out:
# <All keys matched successfully>

# %%
_, predictions, true_vals = evaluate(dataloader_val)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
accuracy_per_class(predictions, true_vals)
# Out:
# Class:Negative
# Accuracy:6/12
#
# Class:Positive
# Accuracy:50/53
#
# Class:Neutral
# Accuracy:1/10

# %%
f1_score_func(predictions, true_vals)
# Out:
# 0.7176393976393975
